# %% [markdown]
# <a href="https://colab.research.google.com/github/asad-maiga/Pandas/blob/main/pandas_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()

# %%
countries = ['United States', 'India', 'Turkey', 'United Kingdom']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']

# %%
filt

# %%
df.loc[filt]
